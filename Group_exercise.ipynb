# %% [markdown]
# <a href="https://colab.research.google.com/github/shannonlal/Statistical-YCBS-255/blob/main/Group_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Diabetes Dataset
# https://www.kaggle.com/uciml/pima-indians-diabetes-database?select=diabetes.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fileName = 'https://raw.githubusercontent.com/abdelrahman-ayad/MiCM-StatsPython-F21/main/data/diabetes.csv'
df = pd.read_csv(fileName)

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
df.Age.isnull().any()
# Out:
# False

# %%
df['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14])

# %%
Age_col = df['Age']
Age_col.head()
# Out:
# 0    50
# 1    31
# 2    32
# 3    21
# 4    33
# Name: Age, dtype: int64

# %%
df['Pregnancies']>1
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 763     True
# 764     True
# 765     True
# 766    False
# 767    False
# Name: Pregnancies, Length: 768, dtype: bool

# %%
df_filter = df[(df['Pregnancies']>1) & (df['Glucose']>120)]
df_filter.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0             6      148             72  ...                     0.627   50        1
# 2             8      183             64  ...                     0.672   32        1
# 8             2      197             70  ...                     0.158   53        1
# 9             8      125             96  ...                     0.232   54        1
# 11           10      168             74  ...                     0.537   34        1
# 12           10      139             80  ...                     1.441   57        0
# 14            5      166             72  ...                     0.587   51        1
# 20            3      126             88  ...                     0.704   27        0
# 22            7      196             90  ...                     0.451   41        1
# 24           11      143             94  ...                     0.254   51        1
# 25           10      125             70  ...                     0.205   41        1
# 26            7      147             76  ...                     0.257   43        1
# 28           13      145             82  ...                     0.245   57        0
# 31            3      158             76  ...                     0.851   28        1
# 34           10      122             78  ...                     0.512   45        0
# 36           11      138             76  ...                     0.420   35        0
# 40            3      180             64  ...                     0.271   26        0
# 41            7      133             84  ...                     0.696   37        0
# 43            9      171            110  ...                     0.721   54        1
# 44            7      159             64  ...                     0.294   40        0
#
# [20 rows x 9 columns]

# %%
df.iloc[0]
# Out:
# Pregnancies                   6.000
# Glucose                     148.000
# BloodPressure                72.000
# SkinThickness                35.000
# Insulin                       0.000
# BMI                          33.600
# DiabetesPedigreeFunction      0.627
# Age                          50.000
# Outcome                       1.000
# Name: 0, dtype: float64

# %%
df.Age.iloc[0]
# Out:
# 50

# %%
df.Outcome.unique()
# Out:
# array([1, 0])

# %%
df.groupby(by='Outcome').Age.mean()
# Out:
# Outcome
# 0    31.190000
# 1    37.067164
# Name: Age, dtype: float64

# %%
df_sorted = df.sort_values(by='Age')
df_sorted.tail(50)
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 39             4      111  ...   56        1
# 717           10       94  ...   56        0
# 542           10       90  ...   56        1
# 28            13      145  ...   57        0
# 344            8       95  ...   57        0
# 206            8      196  ...   57        1
# 12            10      139  ...   57        0
# 278            5      114  ...   57        0
# 299            8      112  ...   58        0
# 512            9       91  ...   58        0
# 375           12      140  ...   58        1
# 557            8      110  ...   58        0
# 487            0      173  ...   58        0
# 53             8      176  ...   58        1
# 388            5      144  ...   58        1
# 13             1      189  ...   59        1
# 475            0      137  ...   59        0
# 319            6      194  ...   59        1
# 186            8      181  ...   60        1
# 30             5      109  ...   60        0
# 519            6      129  ...   60        0
# 212            7      179  ...   60        0
# 93             4      134  ...   60        1
# 223            7      142  ...   61        0
# 115            4      146  ...   61        1
# 129            0      105  ...   62        1
# 456            1      135  ...   62        0
# 579            2      197  ...   62        1
# 582           12      121  ...   62        0
# 763           10      101  ...   63        0
# 263            3      142  ...   63        0
# 479            4      132  ...   63        0
# 361            5      158  ...   63        0
# 509            8      120  ...   64        0
# 294            0      161  ...   65        0
# 362            5      103  ...   65        0
# 148            5      147  ...   65        0
# 221            2      158  ...   66        1
# 552            6      114  ...   66        0
# 495            6      166  ...   66        0
# 759            6      190  ...   66        1
# 489            8      194  ...   67        0
# 537            0       57  ...   67        0
# 363            4      146  ...   67        1
# 674            8       91  ...   68        0
# 123            5      132  ...   69        0
# 684            5      136  ...   69        0
# 666            4      145  ...   70        1
# 453            2      119  ...   72        0
# 459            9      134  ...   81        0
#
# [50 rows x 9 columns]

# %% [markdown]
# # Breakout room exercise
#
# ## In this exercise, the goal is to explore and perform statistical analysis on two data real-world data.

# %% [markdown]
# Q1) Visualize the data to understand the relationships between the variables.
# At least plot BloodPressure vs BMI, BloodPressure vs Age.
# Feel free to use methods such as scatterplots boxplots, histograms, etc.
# Use seaborn and matplotlib as needed
#
# Q2) Does age affect BloodPressure? How can you answer this question (e.g., you can make a plot)
#
# Q3) For people who have diabetes (outcome = 1), what is the probability that their age over 50? (count)
#
# Q4) For people who are over 50, what is the probability they have diabetes (outcome = 1)?
#
# Q5) Is the average Glucose level for people who have diabetes is the same as the average levle for people who don't have diabetes? (Hint: conduct a hypothesis test)
#
# Q6) Can we identify a relationship between any two variables (except outcome)? for example relationship between Glucose and BMI or other variables.  Build a linear regression model using sklearn. What feature(s) will you use? Hint: you can use more than one!. What other models you can use with sklearn?

# %% [markdown]
# ### Split data into train and test
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
print(len( df.Age ))

age_col = df.Age
bp_col = df.BloodPressure
plt.figure(figsize=(7,4))
plt.title("BloodPressure vs Age",fontsize=16)
plt.scatter(age_col, bp_col)
plt.show()

bmi_col = df.BMI
plt.figure(figsize=(7,4))
plt.title("BloodPressure vs BMI",fontsize=16)
plt.scatter(bmi_col, bp_col)
plt.show()

# Q2: Age does not seem to impact Bloodpressure

# Q3: 
df_filter = df[(df.Outcome == 1) & (df.Age > 50)]

df_age_filter = (df.Age > 50)

prob = len(df_filter.Age)/ len( df_age_filter)

print( prob )

## We found 38 people who had Diabiates and are over 50 years old

# Q4


df_diabetes = df[df.Outcome == 1]

print (df_diabetes.Glucose.mean() )

df_non_diabetes = df[df.Outcome == 0]
print( df_non_diabetes.Glucose.mean())

# Anser is no.  People with Diabetes have higher levels of average Glucose

#6 Linear Regression

from sklearn import linear_model
reg = linear_model.LinearRegression()
#The following line will throw an error. Regfit requires a specific shape of the s and y array. Must reshape the data first
df_glucose = df.Glucose
df_glucose.reshape( 1, -1)
df_bmi = df.BMI
df_bmi.reshape( 1,-1)

reg.fit( df_glucose, df_bmi )

# plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)
# Out:
# 768
# 0.049479166666666664
# 141.25746268656715
# 109.98
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-1c69851180fd> in <module>()
#      45 #The following line will throw an error. Regfit requires a specific shape of the s and y array. Must reshape the data first
#      46 df_glucose = df.Glucose
# ---> 47 df_glucose.reshape( 1, -1)
#      48 df_bmi = df.BMI
#      49 df_bmi.reshape( 1,-1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'reshape'
